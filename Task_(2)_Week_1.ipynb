# %% [markdown]
# <a href="https://colab.research.google.com/github/thabetAljbreen/RepoT5/blob/main/Task_(2)_Week_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Objective
# * The objective of this exercise is to explore and visualize the Traffic Index dataset to gain insights and understand the patterns in the data.

# %% [markdown]
# ##Dataset Description

# %% [markdown]
# | Column Name | Description | Data Type |
# | :---------------- | :------: | ----: |
# |   City  |   Name of the city	   | Object |
# | Datetime           |   Date and time of the data entry	   | Object |
# |  TrafficIndexLive    |  Real-time traffic index	   | Int |
# |  Jamscount |  Number of traffic jams	   | Int |
# |   JamsDelay  |   Total delay caused by traffic jams (in minutes)	   | Float |
# |JamsLength           |   Total length of traffic jams (in kilometers)	   | Float |
# |  TrafficIndexWeekAgo    |  Traffic index one week ago	   | Int |
# |  TravelTimeHistoric |  Historical average travel time (in minutes)	   | Float |
# |   TravelTimeLive  |   Real-time travel time (in minutes)	   | Float |

# %% [markdown]
# # Tasks

# %% [markdown]
# ## 1. Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Perform summary statistics on the dataset.

# %%
import pandas as pd
df=pd.read_csv('/content/Task (2) Dataset.csv')

# %%
df.isnull().sum()
# Out:
# City                      0
# Datetime                  0
# TrafficIndexLive          0
# JamsCount                 0
# JamsDelay                 0
# JamsLength                0
# TrafficIndexWeekAgo       0
# TravelTimeHistoric     3867
# TravelTimeLive         3867
# dtype: int64

# %%
df.head()
# Out:
#        City             Datetime  TrafficIndexLive  JamsCount  JamsDelay  \
# 0  Abudhabi  2023-07-07 08:01:30                 6          4       15.6
# 1  Abudhabi  2023-07-07 09:01:30                 7          7       20.5
# 2  Abudhabi  2023-07-07 10:46:30                 7          8       25.0
# 3  Abudhabi  2023-07-07 11:16:30                 8         11       30.6
# 4  Abudhabi  2023-07-07 12:01:30                 8         20       62.1
#
#    JamsLength  TrafficIndexWeekAgo  TravelTimeHistoric  TravelTimeLive
# 0         0.7                   13           59.611918       54.803617
# 1         1.7                    8           60.221387       56.118629
# 2         2.8                    6           59.161978       55.518834
# 3         5.5                    6           59.738138       56.413917
# 4         6.5                    5           58.958314       56.059246

# %%
df.describe()
# Out:
#        TrafficIndexLive     JamsCount     JamsDelay    JamsLength  \
# count      66639.000000  66639.000000  66639.000000  66639.000000
# mean          14.043113     74.278531    288.353877     49.316135
# std           13.488906    107.452022    470.013224     85.352525
# min            0.000000      0.000000      0.000000      0.000000
# 25%            3.000000      9.000000     27.700000      3.000000
# 50%           10.000000     29.000000     95.700000     12.200000
# 75%           21.000000     95.000000    336.600000     53.500000
# max          138.000000   1359.000000   9989.400000   1173.900000
#
#        TrafficIndexWeekAgo  TravelTimeHistoric  TravelTimeLive
# count         66639.000000        62772.000000    62772.000000
# mean             13.981737           70.706601       70.048451
# std              13.454922           10.588384       11.966725
# min               0.000000           49.381346       46.723235
# ...

# %% [markdown]
# ### Identify and analyze patterns in the data.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66639 entries, 0 to 66638
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   City                 66639 non-null  object
#  1   Datetime             66639 non-null  object
#  2   TrafficIndexLive     66639 non-null  int64
#  3   JamsCount            66639 non-null  int64
#  4   JamsDelay            66639 non-null  float64
#  5   JamsLength           66639 non-null  float64
#  6   TrafficIndexWeekAgo  66639 non-null  int64
#  7   TravelTimeHistoric   62772 non-null  float64
#  8   TravelTimeLive       62772 non-null  float64
# dtypes: float64(4), int64(3), object(2)
# memory usage: 4.6+ MB

# %%
#if date was not object
date_ser=pd.Series(df.Datetime)
print(date_ser)
date_ser=pd.to_datetime(date_ser)
print(date_ser)
# Out:
# 0        2023-07-07 08:01:30
# 1        2023-07-07 09:01:30
# 2        2023-07-07 10:46:30
# 3        2023-07-07 11:16:30
# 4        2023-07-07 12:01:30
#                 ...
# 66634    2023-12-15 03:01:30
# 66635    2023-12-15 04:31:30
# 66636    2023-12-15 05:01:30
# 66637    2023-12-15 06:01:30
# 66638    2023-12-15 07:01:30
# Name: Datetime, Length: 66639, dtype: object
# 0       2023-07-07 08:01:30
# 1       2023-07-07 09:01:30
# 2       2023-07-07 10:46:30
# 3       2023-07-07 11:16:30
# 4       2023-07-07 12:01:30
#                 ...
# 66634   2023-12-15 03:01:30
# 66635   2023-12-15 04:31:30
# 66636   2023-12-15 05:01:30
# 66637   2023-12-15 06:01:30
# 66638   2023-12-15 07:01:30
# Name: Datetime, Length: 66639, dtype: datetime64[ns]

# %%
date_ser=pd.to_datetime(date_ser,format='%y%m%d')

# %%
#i will do it for just three

df['year']=date_ser.dt.year
df['month']=date_ser.dt.month
df['day']=date_ser.dt.day
df
# Out:
#            City             Datetime  TrafficIndexLive  JamsCount  JamsDelay  \
# 0      Abudhabi  2023-07-07 08:01:30                 6          4       15.6
# 1      Abudhabi  2023-07-07 09:01:30                 7          7       20.5
# 2      Abudhabi  2023-07-07 10:46:30                 7          8       25.0
# 3      Abudhabi  2023-07-07 11:16:30                 8         11       30.6
# 4      Abudhabi  2023-07-07 12:01:30                 8         20       62.1
# ...         ...                  ...               ...        ...        ...
# 66634    Riyadh  2023-12-15 03:01:30                 8         33      127.8
# 66635    Riyadh  2023-12-15 04:31:30                 6         27       87.0
# 66636    Riyadh  2023-12-15 05:01:30                 3         17       49.8
# 66637    Riyadh  2023-12-15 06:01:30                 0         16       61.3
# 66638    Riyadh  2023-12-15 07:01:30                 0         15       39.5
#
# ...

# %% [markdown]
# ### Visualize the distribution of key variables (e.g., Traffic_Index, Date).

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
num_column=df[['JamsCount','JamsDelay','JamsLength','TravelTimeHistoric','']]
corr_matrix=num_column.corr()
# print(corr_matrix)


plt.figure(figsize=(15,10))
sns.heatmap(corr_matrix, annot=True)
plt.title('corr')
plt.show()

# %%
num_column=df[['TravelTimeHistoric','TravelTimeLive']]
corr_matrix=num_column.corr()
# print(corr_matrix)


plt.figure(figsize=(15,10))
sns.heatmap(corr_matrix, annot=True)
plt.title('corr')
plt.show()

# %%
num_column=df[['JamsCount','JamsDelay','JamsLength','TravelTimeHistoric','TravelTimeLive']]
corr_matrix=num_column.corr()
# print(corr_matrix)

plt.figure(figsize=(15,10))
sns.heatmap(corr_matrix, annot=True)
plt.title('corr')
plt.show()

# %% [markdown]
# ### Explore relationships between variables (e.g., Traffic_Index vs. Weather_Condition).

# %%
jamsCount=df.groupby('City').agg(
    total_JamsCount=('JamsCount','sum'),
    total_JamsDelay=('JamsDelay','sum'),
    total_JamsLength=('JamsLength','sum'),
    total_TravelTimeHistoric=('TravelTimeHistoric','sum'),
    total_TravelTimeLive=('TravelTimeLive','sum'),
    avg_JamsCount=('JamsCount','mean'),
    avg_JamsDelay=('JamsDelay','mean'),
    avg_JamsLength=('JamsLength','mean'),
    avg_TravelTimeHistoric=('TravelTimeHistoric','mean'),
    avg_TravelTimeLive=('TravelTimeLive','mean'),
    min_JamsCount=('JamsCount','min'),
    min_JamsDelay=('JamsDelay','min'),
    min_JamsLength=('JamsLength','min'),
    min_TravelTimeHistoric=('TravelTimeHistoric','min'),
    min_TravelTimeLive=('TravelTimeLive','min'),
    max_JamsCount=('JamsCount','max'),
    max_JamsDelay=('JamsDelay','max'),
    max_JamsLength=('JamsLength','max'),
    max_TravelTimeHistoric=('TravelTimeHistoric','max'),
    max_TravelTimeLive=('TravelTimeLive','max')



)
# print(jamsCount)
r=[]
r=jamsCount
# print(r['total_JamsCount'])

x=['Abudhabi','Al-ain','Cairo','Dammam','Doha','Dubai','Jeddah','Kuwait','Mecca','Medina','Riyadh']
y=['115421','26421','567476','130124','364277','1609530','188733','592523','46079','41080','1268183']
fig, ax = plt.subplots()
ax.bar(x, y)

ax.set_ylabel('total jams count')
ax.set_title('Fruit supply by kind and color')

# r['max_JamsCount'].value_counts().sort_index().plot.line()
# plt.pie()
# Out:
# Text(0.5, 1.0, 'Fruit supply by kind and color')

# %% [markdown]
# #i can do the rest but it is gonna take lots of time(if i used google i am sure there is better way)

# %% [markdown]
# ## 2. Data Visualization

# %% [markdown]
# * Ensure the visualizations are clear and informative.

# %% [markdown]
# ### Create visualizations to illustrate the findings from the EDA.

# %%
import numpy as np
import matplotlib.pyplot as plt
ax.barh(np.arange(len(y)), x, xerr=np.random.rand(len(y)), align='center')
ax.set_yticks(np.arange(len(y)),labels=y)
ax.set_xlabel(x)
plt.show()

# %%
r=jamsCount
# print(r['total_JamsCount'])

x=['Abudhabi','Al-ain','Cairo','Dammam','Doha','Dubai','Jeddah','Kuwait','Mecca','Medina','Riyadh']
y=['115421','26421','567476','130124','364277','1609530','188733','592523','46079','41080','1268183']
fig, ax = plt.subplots()
ax.bar(x, y)
ax.set_ylabel('total jams count')
ax.set_title('jams ccount')
# Out:
# Text(0.5, 1.0, 'jams ccount')

# %%
fig, axs = plt.subplots(1, 3, figsize=(30, 8), sharey=True)
axs[0].bar(x, y)
axs[1].scatter(x, y)
axs[2].plot(x, y)
fig.suptitle('Categorical Plotting')
# Out:
# Text(0.5, 0.98, 'Categorical Plotting')

# %% [markdown]
# ### Use appropriate plots such as histograms, bar charts, pie charts, scatter plots, and heatmaps.

# %%
fig, ax = plt.subplots()
ax.bar(x, y)

ax.set_ylabel('total jams count')
ax.set_title('Fruit supply by kind and color')
######there is hige problem
# Out:
# Text(0.5, 1.0, 'Fruit supply by kind and color')

# %%
# fig, ax = plt.subplots()
# ax.pie(x, y)
# ax.bar(x, df.JamsCount)
ax.set_ylabel('total jams count')
ax.set_title('Fruit supply by kind and color')
# ax.set_ylabel('total jams count')
# ax.set_title('Fruit supply by kind and color')
# Out:
# Text(0.5, 1.0, 'Fruit supply by kind and color')

# %%
(df['City'].value_counts()).plot.bar()
# Out:
# <Axes: xlabel='City'>

# %%
(df['year'].value_counts()).plot.bar()
# Out:
# <Axes: xlabel='year'>

# %%
(df['month'].value_counts()).plot.bar()
## months like 7 to 11 is more than the rest months
# Out:
# <Axes: xlabel='month'>

# %%
(df['day'].value_counts()).plot.bar()
## al the dayas are the same
# Out:
# <Axes: xlabel='day'>

# %% [markdown]
# * <h3>Summarize the key insights gained from the data analysis.<h3/>
# * <h3>Draw conclusions based on the patterns observed in the data.<h3/>

# %% [markdown]
# ###*I noticed that  Doha, Riyadh,Cairo, Kwait and Dubai is the most cites that have a lot of accdents there*

# %% [markdown]
# ###*Also months like 7 to 11 is more than the rest months maybe because of the weather*

# %% [markdown]
# ###*Furthermure I noticed that all the days are the same there are no diffrences*

# %% [markdown]
# ###*there is also strong collration between jam counts and jamslength and fine correlation between all jams and travel time live*

# %% [markdown]
# avrage travel live time is almost 70
